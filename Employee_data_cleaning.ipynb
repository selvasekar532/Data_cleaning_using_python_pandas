# %%
# Importing pandas

# %%
import pandas as pd

# %%
# Reading the excel file

# %%
df = pd.read_excel("C:/Users/selva/Downloads/Chat_Gpt_For_Pandas.xlsx")

# %%
# selecting all the data from the DataFrame

# %%
df
# Out:
#        ID     Name    Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John  forty  Female     9876543210  50000                  NaN
# 1       2      NaN     40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael     45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah  forty       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna     35       F          Phone  60000  2022-05-15 00:00:00
# ...   ...      ...    ...     ...            ...    ...                  ...
# 1005  243  Michael     40       F  (123)-456-789    NaN                  NaN
# 1006  297   Robert     40       F     9876543210  60000  2022-05-15 00:00:00
# 1007  153  Michael     35     NaN     1234567890  80000  2023-05-01 00:00:00
# 1008   38  Jessica     40  Female            NaN  50000  2023-05-01 00:00:00
# 1009  660    Emily     40    Male            NaN  70000  2022-05-15 00:00:00
#
# ...

# %%
# Finding the duplicate values

# %%
duplicates = df[df.duplicated()]

# %%
duplicates
# Out:
#        ID     Name  Age  Gender   Phone Number Salary            Join Date  \
# 1000  948  Jessica   30       F     1234567890    NaN  2023-05-01 00:00:00
# 1001  345     Anna  NaN     NaN          Phone  80000  2021-01-10 00:00:00
# 1002  451     John   30    Male          Phone    NaN  2021-01-10 00:00:00
# 1003  933  Michael   30   Other       12345abc  70000                  NaN
# 1004  360    Emily   30  Female     1234567890  50000  2022-05-15 00:00:00
# 1005  243  Michael   40       F  (123)-456-789    NaN                  NaN
# 1006  297   Robert   40       F     9876543210  60000  2022-05-15 00:00:00
# 1007  153  Michael   35     NaN     1234567890  80000  2023-05-01 00:00:00
# 1008   38  Jessica   40  Female            NaN  50000  2023-05-01 00:00:00
# 1009  660    Emily   40    Male            NaN  70000  2022-05-15 00:00:00
#
#      Experience (Years)   Department                 Country
# 1000                  3        Admin  USA, California, 90210
# ...

# %%
# Droping all the duplicate rows

# %%
df.drop_duplicates(inplace = True)

# %%
# Recheck the column count after drop all the duplicate rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                801 non-null    object
#  2   Age                 865 non-null    object
#  3   Gender              792 non-null    object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    object
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 85.9+ KB

# %%
df
# Out:
#        ID     Name    Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John  forty  Female     9876543210  50000                  NaN
# 1       2      NaN     40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael     45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah  forty       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna     35       F          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...    ...     ...            ...    ...                  ...
# 995   996      NaN    NaN       F       12345abc    NaN                  NaN
# 996   997   Robert     25  Female     9876543210    NaN                  NaN
# 997   998  Jessica  forty       F     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David     40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily    NaN     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
# ...

# %%
# Finding the most repeadted name...

# %%
most = df['Name'].value_counts().idxmax()

# %%
most
# Out:
# 'John'

# %%
# Replacing all the null values with the most repeated value

# %%
df['Name'].fillna(most,inplace = True)

# %%
# Printing all the values to see everthing gets changed or not!

# %%
df
# Out:
#        ID     Name    Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John  forty  Female     9876543210  50000                  NaN
# 1       2     John     40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael     45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah  forty       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna     35       F          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...    ...     ...            ...    ...                  ...
# 995   996     John    NaN       F       12345abc    NaN                  NaN
# 996   997   Robert     25  Female     9876543210    NaN                  NaN
# 997   998  Jessica  forty       F     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David     40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily    NaN     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
# ...

# %%
# Change the one numerical value to most repeated value

# %%
df['Name'].replace(12345, most, inplace = True)

# %%
# Checking the changes has been made!

# %%
df
# Out:
#        ID     Name    Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John  forty  Female     9876543210  50000                  NaN
# 1       2     John     40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael     45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah  forty       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna     35       F          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...    ...     ...            ...    ...                  ...
# 995   996     John    NaN       F       12345abc    NaN                  NaN
# 996   997   Robert     25  Female     9876543210    NaN                  NaN
# 997   998  Jessica  forty       F     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David     40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily    NaN     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 865 non-null    object
#  3   Gender              792 non-null    object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    object
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 85.9+ KB

# %%
# Changing the age datatype from object to numeric

# %%
df['Age'] = pd.to_numeric(df['Age'], errors = 'coerce')

# %%
df['Age'].dtypes
# Out:
# dtype('float64')

# %%
# Checking the column format is converted

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 726 non-null    float64
#  3   Gender              792 non-null    object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    object
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 85.9+ KB

# %%
df
# Out:
#        ID     Name   Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John   NaN  Female     9876543210  50000                  NaN
# 1       2     John  40.0     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael  45.0    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah   NaN       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna  35.0       F          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...   ...     ...            ...    ...                  ...
# 995   996     John   NaN       F       12345abc    NaN                  NaN
# 996   997   Robert  25.0  Female     9876543210    NaN                  NaN
# 997   998  Jessica   NaN       F     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David  40.0    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily   NaN     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
# ...

# %%
# Finding the mean value of age column

# %%
age_mean = df['Age'].mean()

# %%
age_mean
# Out:
# 35.02066115702479

# %%
# Replacing the NaN cells with the mean value of 'age'

# %%
df['Age'] = df['Age'].fillna(age_mean)

# %%
# Checking the Datatype has been changed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   float64
#  3   Gender              792 non-null    object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    object
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 85.9+ KB

# %%
# Converting age(float) to age(int)

# %%
df['Age'] = df['Age'].astype(int)

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John   35  Female     9876543210  50000                  NaN
# 1       2     John   40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah   35       F     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna   35       F          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...    ...                  ...
# 995   996     John   35       F       12345abc    NaN                  NaN
# 996   997   Robert   25  Female     9876543210    NaN                  NaN
# 997   998  Jessica   35       F     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily   35     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
#     Experience (Years)   Department                    Country
# ...

# %%
# Counting the values of gender column

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    204
# Male      202
# F         202
# Other     184
# Name: count, dtype: int64

# %%
# Replacing the 'F' column to 'Female'

# %%
df['Gender'] = df['Gender'].replace('F','Female')

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John   35  Female     9876543210  50000                  NaN
# 1       2     John   40     NaN          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah   35  Female     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna   35  Female          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...    ...                  ...
# 995   996     John   35  Female       12345abc    NaN                  NaN
# 996   997   Robert   25  Female     9876543210    NaN                  NaN
# 997   998  Jessica   35  Female     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily   35     NaN  (123)-456-789    60k  2023-05-01 00:00:00
#
#     Experience (Years)   Department                    Country
# ...

# %%
# Checking the most repeated values in gender column

# %%
most_gender = df['Gender'].value_counts().idxmax()

# %%
most_gender
# Out:
# 'Female'

# %%
# Filling the NaN values using the most repeated value

# %%
df['Gender'].fillna(most_gender,inplace = True)

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John   35  Female     9876543210  50000                  NaN
# 1       2     John   40  Female          Phone    60k  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah   35  Female     9876543210    60k  2022-05-15 00:00:00
# 4       5     Anna   35  Female          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...    ...                  ...
# 995   996     John   35  Female       12345abc    NaN                  NaN
# 996   997   Robert   25  Female     9876543210    NaN                  NaN
# 997   998  Jessica   35  Female     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily   35  Female  (123)-456-789    60k  2023-05-01 00:00:00
#
#     Experience (Years)   Department                    Country
# ...

# %%
# Checking the datatype of gender column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    object
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 82.0+ KB

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    614
# Male      202
# Other     184
# Name: count, dtype: int64

# %%
# Converting the salary values to proper format

# %%
sal = {
    '10k' : 10000,
    '20k' : 20000,
    '30k' : 30000,
    '40k' : 40000,
    '50k' : 50000,
    '60k' : 60000,
    '70k' : 70000,
    '80k' : 80000,
    '90k' : 90000
}

# %%
# Converting the mismatched formats to proper format like(60k to 60000)

# %%
df['Salary'].replace(sal,inplace = True)

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number Salary            Join Date  \
# 0       1     John   35  Female     9876543210  50000                  NaN
# 1       2     John   40  Female          Phone  60000  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789  60000  2022-05-15 00:00:00
# 3       4    Sarah   35  Female     9876543210  60000  2022-05-15 00:00:00
# 4       5     Anna   35  Female          Phone  60000  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...    ...                  ...
# 995   996     John   35  Female       12345abc    NaN                  NaN
# 996   997   Robert   25  Female     9876543210    NaN                  NaN
# 997   998  Jessica   35  Female     9876543210    NaN  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone  80000  2021-01-10 00:00:00
# 999  1000    Emily   35  Female  (123)-456-789  60000  2023-05-01 00:00:00
#
#     Experience (Years)   Department                    Country
# ...

# %%
# Checking how many distinct values are there in the df

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 60000    267
# 70000    155
# 80000    149
# 50000    148
# abcd       1
# Name: count, dtype: int64

# %%
# Counting how many NaN and Non NaN values are there

# %%
df['Salary'].isnull().value_counts()
# Out:
# Salary
# False    720
# True     280
# Name: count, dtype: int64

# %%
# Replacing the abcd to random value of 80000

# %%
df['Salary'].replace('abcd', 80000,inplace = True)

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 60000.0    267
# 70000.0    155
# 80000.0    150
# 50000.0    148
# Name: count, dtype: int64

# %%
# Converting the salary column format from object to float

# %%
df['Salary'] = pd.to_numeric(df['Salary'])

# %%
# Checking the changes has been made

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              720 non-null    float64
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
# Finding out the median value of salary column

# %%
salary_median = df['Salary'].median()

# %%
salary_median
# Out:
# 60000.0

# %%
# Filling all the NaN values with the median value of salary column

# %%
df['Salary'] = df['Salary'].fillna(salary_median)

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number   Salary            Join Date  \
# 0       1     John   35  Female     9876543210  50000.0                  NaN
# 1       2     John   40  Female          Phone  60000.0  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789  60000.0  2022-05-15 00:00:00
# 3       4    Sarah   35  Female     9876543210  60000.0  2022-05-15 00:00:00
# 4       5     Anna   35  Female          Phone  60000.0  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...      ...                  ...
# 995   996     John   35  Female       12345abc  60000.0                  NaN
# 996   997   Robert   25  Female     9876543210  60000.0                  NaN
# 997   998  Jessica   35  Female     9876543210  60000.0  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone  80000.0  2021-01-10 00:00:00
# 999  1000    Emily   35  Female  (123)-456-789  60000.0  2023-05-01 00:00:00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              1000 non-null   float64
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
# Converting the salary(float) to salary(int)

# %%
df['Salary'] = df['Salary'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              1000 non-null   int32
#  6   Join Date           796 non-null    object
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: int32(2), int64(1), object(7)
# memory usage: 78.1+ KB

# %%
# Checking the 'Join Date' column to clean

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary            Join Date  \
# 0       1     John   35  Female     9876543210   50000                  NaN
# 1       2     John   40  Female          Phone   60000  2022-05-15 00:00:00
# 2       3  Michael   45    Male  (123)-456-789   60000  2022-05-15 00:00:00
# 3       4    Sarah   35  Female     9876543210   60000  2022-05-15 00:00:00
# 4       5     Anna   35  Female          Phone   60000  2022-05-15 00:00:00
# ..    ...      ...  ...     ...            ...     ...                  ...
# 995   996     John   35  Female       12345abc   60000                  NaN
# 996   997   Robert   25  Female     9876543210   60000                  NaN
# 997   998  Jessica   35  Female     9876543210   60000  2023-05-01 00:00:00
# 998   999    David   40    Male          Phone   80000  2021-01-10 00:00:00
# 999  1000    Emily   35  Female  (123)-456-789   60000  2023-05-01 00:00:00
#
# ...

# %%
df['Join Date'].value_counts()
# Out:
# Join Date
# 2022-05-15 00:00:00    379
# 2021-01-10 00:00:00    220
# 2023-05-01 00:00:00    196
# 12-34-2022               1
# Name: count, dtype: int64

# %%
# Converting 'Join Date' column to datetime format

# %%
df['Join Date'] = pd.to_datetime(df['Join Date'],errors = 'coerce')

# %%
# Checking whether its changed or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              1000 non-null   int32
#  6   Join Date           795 non-null    datetime64[ns]
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(6)
# memory usage: 78.1+ KB

# %%
# Filling the NaN values using forward fill functio

# %%
df['Join Date'] = df['Join Date'].fillna(method = 'ffill')
# Out:
# C:\Users\selva\AppData\Local\Temp\ipykernel_6060\777700102.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Join Date'] = df['Join Date'].fillna(method = 'ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  1000 non-null   int64
#  1   Name                1000 non-null   object
#  2   Age                 1000 non-null   int32
#  3   Gender              1000 non-null   object
#  4   Phone Number        864 non-null    object
#  5   Salary              1000 non-null   int32
#  6   Join Date           999 non-null    datetime64[ns]
#  7   Experience (Years)  825 non-null    object
#  8   Department          900 non-null    object
#  9   Country             826 non-null    object
# dtypes: datetime64[ns](1), int32(2), int64(1), object(6)
# memory usage: 78.1+ KB

# %%
df['Join Date'].value_counts()
# Out:
# Join Date
# 2022-05-15    476
# 2021-01-10    275
# 2023-05-01    248
# Name: count, dtype: int64

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000        NaT
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#     Experience (Years)   Department                    Country
# 0                    7        Sales                        NaN
# ...

# %%
# While cleaning the Join Date column there is one NaT value at the top of the column so the forward fill function doesn't apply there and to convert that i have used backward fill

# %%
df['Join Date'] = df['Join Date'].fillna(method = 'bfill')
# Out:
# C:\Users\selva\AppData\Local\Temp\ipykernel_6060\1358303200.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Join Date'] = df['Join Date'].fillna(method = 'bfill')

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#     Experience (Years)   Department                    Country
# 0                    7        Sales                        NaN
# ...

# %%
# Creating a dictonariy with some values for replacing the values in the experience column

# %%
exp = {
    'One' : 1,
    'Two' : 2,
    'three' : 3,
    'Four' : 4,
    'five' : 5,
    'Six' : 6,
    'Seven' : 7,
    'Eight' : 8,
    'Nine' : 9,
    'Ten' : 10
}

# %%
# This is the code where i have replacing the values into the 'experience' column

# %%
df['Experience (Years)'].replace(exp,inplace = True)

# %%
# Checking how many unique values values are there in a column to find out to change anything manually

# %%
df['Experience (Years)'].value_counts()
# Out:
# Experience (Years)
# 3        339
# 7        174
# 5        166
# 1        145
# fifty      1
# Name: count, dtype: int64

# %%
# Use the bill() to fill the NaN values

# %%
df['Experience (Years)'] = df['Experience (Years)'].fillna(method = 'bfill')
# Out:
# C:\Users\selva\AppData\Local\Temp\ipykernel_6060\3707691092.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Experience (Years)'] = df['Experience (Years)'].fillna(method = 'bfill')

# %%
df['Experience (Years)'].value_counts()
# Out:
# Experience (Years)
# 3        416
# 5        205
# 7        201
# 1        177
# fifty      1
# Name: count, dtype: int64

# %%
# Changing manually a 'fifty' value

# %%
df ['Experience (Years)'] = df['Experience (Years)'].replace('fifty', 1)

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#      Experience (Years)   Department                    Country
# 0                     7        Sales                        NaN
# ...

# %%
df['Experience (Years)'].value_counts().sum()
# Out:
# 1000

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#      Experience (Years)   Department                    Country
# 0                     7        Sales                        NaN
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# Sales          100
# HR             100
# Engineering    100
# Marketing      100
# HR3            100
# 123            100
# Admin          100
# Support        100
# Tech           100
# Name: count, dtype: int64

# %%
# Changing the 123 value to Business analyst

# %%
df['Department'] = df['Department'].replace('123', 'Business analyst')

# %%
df['Department'].value_counts()
# Out:
# Department
# Sales               100
# HR                  100
# Engineering         100
# Marketing           100
# HR3                 100
# Business analyst    100
# Admin               100
# Support             100
# Tech                100
# Name: count, dtype: int64

# %%
# Changing the 'HR3' to 'HR'

# %%
df['Department'] = df['Department'].replace('HR3', 'HR')

# %%
df['Department'].value_counts()
# Out:
# Department
# HR                  200
# Sales               100
# Engineering         100
# Marketing           100
# Business analyst    100
# Admin               100
# Support             100
# Tech                100
# Name: count, dtype: int64

# %%
# Just using the bfill() to fill the all NaN values

# %%
df['Department'] = df['Department'].bfill()

# %%
df['Department'].value_counts()
# Out:
# Department
# HR                  300
# Sales               100
# Engineering         100
# Marketing           100
# Business analyst    100
# Admin               100
# Support             100
# Tech                100
# Name: count, dtype: int64

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#      Experience (Years)        Department                    Country
# 0                     7             Sales                        NaN
# ...

# %%
split_data = df['Country'].str.split(',', expand = True)

# %%
split_data.columns = ['Country','State','ZipCode']

# %%
df['Country'] = split_data['Country']
df['State'] = split_data['State']
df['ZipCode'] = split_data['ZipCode']

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#      Experience (Years)        Department  Country        State  ZipCode
# 0                     7             Sales      NaN          NaN      NaN
# ...

# %%
df['ZipCode'].value_counts().sum()
# Out:
# 650

# %%
country_repeated = df['Country'].value_counts().idxmax()

# %%
country_repeated
# Out:
# 'France'

# %%
df['Country'] = df['Country'].fillna(country_repeated)

# %%
df['Country'].value_counts().sum()
# Out:
# 1000

# %%
df
# Out:
#        ID     Name  Age  Gender   Phone Number  Salary  Join Date  \
# 0       1     John   35  Female     9876543210   50000 2022-05-15
# 1       2     John   40  Female          Phone   60000 2022-05-15
# 2       3  Michael   45    Male  (123)-456-789   60000 2022-05-15
# 3       4    Sarah   35  Female     9876543210   60000 2022-05-15
# 4       5     Anna   35  Female          Phone   60000 2022-05-15
# ..    ...      ...  ...     ...            ...     ...        ...
# 995   996     John   35  Female       12345abc   60000 2021-01-10
# 996   997   Robert   25  Female     9876543210   60000 2021-01-10
# 997   998  Jessica   35  Female     9876543210   60000 2023-05-01
# 998   999    David   40    Male          Phone   80000 2021-01-10
# 999  1000    Emily   35  Female  (123)-456-789   60000 2023-05-01
#
#      Experience (Years)        Department  Country        State  ZipCode
# 0                     7             Sales   France          NaN      NaN
# ...
